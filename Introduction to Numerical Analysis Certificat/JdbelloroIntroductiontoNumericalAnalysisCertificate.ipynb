# %% [markdown]
# #Coursera Certificate for Introduction to numerical analysis

# %% [markdown]
# ##Linkedin Link:

# %% [markdown]
# https://www.linkedin.com/feed/update/urn:li:activity:6830554066033242112/

# %% [markdown]
# ##Screenshot:

# %% [markdown]
# ![fd238295-159e-4ffa-b73d-a8a98e992db0.jpg](data:image/jpeg;base64,...)
