# %% [markdown]
# #Amazon

# %%
class BootCampTask(QCAlgorithm):

    def Initialize(self):
        self.SetStartDate(2018, 11, 4)
        self.SetEndDate(2021, 12, 4)

        #1,2. Select AMZN minute resolution data and set it to Raw normalization mode
        self.iwm = self.AddEquity("AMZN", Resolution.Minute)
        self.iwm.SetDataNormalizationMode(DataNormalizationMode.Raw)

    def OnData(self, data):

        #3. Place an order for 100 shares of AMZN and print the average fill price
        #4. Debug the AveragePrice of AMZN
        if not self.Portfolio.Invested:
            self.MarketOrder("AMZN", 100)
            self.Debug(str(self.Portfolio["AMZN"].AveragePrice))

# %% [markdown]
# ![amazon.png](data:image/png;base64,...)

# %% [markdown]
# #Oracle

# %%
class BootCampTask(QCAlgorithm):

    def Initialize(self):
        self.SetStartDate(2018, 11, 4)
        self.SetEndDate(2021, 12, 4)

        #1,2. Select ORCL minute resolution data and set it to Raw normalization mode
        self.iwm = self.AddEquity("ORCL", Resolution.Minute)
        self.iwm.SetDataNormalizationMode(DataNormalizationMode.Raw)

    def OnData(self, data):

        #3. Place an order for 100 shares of ORCL and print the average fill price
        #4. Debug the AveragePrice of ORCL
        if not self.Portfolio.Invested:
            self.MarketOrder("ORCL", 100)
            self.Debug(str(self.Portfolio["ORCL"].AveragePrice))

# %% [markdown]
# ![Oracle.png](data:image/png;base64,...)

# %% [markdown]
# #IBM

# %%
class BootCampTask(QCAlgorithm):

    def Initialize(self):
        self.SetStartDate(2018, 11, 4)
        self.SetEndDate(2021, 12, 4)

        #1,2. Select IBM minute resolution data and set it to Raw normalization mode
        self.iwm = self.AddEquity("IBM", Resolution.Minute)
        self.iwm.SetDataNormalizationMode(DataNormalizationMode.Raw)

    def OnData(self, data):

        #3. Place an order for 100 shares of IBM and print the average fill price
        #4. Debug the AveragePrice of IBM
        if not self.Portfolio.Invested:
            self.MarketOrder("IBM", 100)
            self.Debug(str(self.Portfolio["IBM"].AveragePrice))

# %% [markdown]
# ![IBM.png](data:image/png;base64,...)

# %% [markdown]
# #Google

# %%
class BootCampTask(QCAlgorithm):

    def Initialize(self):
        self.SetStartDate(2018, 11, 4)
        self.SetEndDate(2021, 12, 4)

        #1,2. Select GOOG minute resolution data and set it to Raw normalization mode
        self.iwm = self.AddEquity("GOOG", Resolution.Minute)
        self.iwm.SetDataNormalizationMode(DataNormalizationMode.Raw)

    def OnData(self, data):

        #3. Place an order for 100 shares of GOOG and print the average fill price
        #4. Debug the AveragePrice of GOOG
        if not self.Portfolio.Invested:
            self.MarketOrder("GOOG", 100)
            self.Debug(str(self.Portfolio["GOOG"].AveragePrice))

# %% [markdown]
# ![Google.png](data:image/png;base64,...)

# %% [markdown]
# #Apple

# %%
class BootCampTask(QCAlgorithm):

    def Initialize(self):
        self.SetStartDate(2018, 11, 4)
        self.SetEndDate(2021, 12, 4)

        #1,2. Select AAPL minute resolution data and set it to Raw normalization mode
        self.iwm = self.AddEquity("AAPL", Resolution.Minute)
        self.iwm.SetDataNormalizationMode(DataNormalizationMode.Raw)

    def OnData(self, data):

        #3. Place an order for 100 shares of AAPL and print the average fill price
        #4. Debug the AveragePrice of AAPL
        if not self.Portfolio.Invested:
            self.MarketOrder("AAPL", 100)
            self.Debug(str(self.Portfolio["AAPL"].AveragePrice))

# %% [markdown]
# ![Apple.png](data:image/png;base64,...)
